# %% [markdown]
# <a href="https://colab.research.google.com/github/aljiro/dnnls_lecture_notes_exercises/blob/main/assessment/assessment_investigation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![DNNLS module banner](../lecture_notes/images/DNNLS_Logo.png)
#
# # Independent Architecture Investigation
#
# Use the architecture as an experimental system. Your task is to ask a meaningful question, make a justified prediction, design a controlled investigation, use Gemini critically, collect evidence, and decide what the evidence supports.
#
# **Complexity is not a marking criterion.** A careful investigation of a simple reference model can score as highly as a substantially different architecture if the reasoning and evidence are strong.
#
# Read the full brief in [`assessment/README.md`](README.md) before starting.

# %% [markdown]
# ## Choose an investigation route
#
# Choose the route that best matches your question. All routes use the same marking criteria.
#
# - **A — Investigate the existing architecture:** extend or deepen one of the practical investigations.
# - **B — Make an important change:** replace or substantially modify one component and test the consequences.
# - **C — Build an alternative architecture:** for example, compare a Transformer + CLIP approach with the reference architecture.
# - **D — Ask a scientific question:** use the architecture to test a claim about what or how it learns, for example whether it learns a concept of place.
#
# Your question may evolve after preliminary evidence. If it does, record what changed and why.

# %% [markdown]
# ## Gemini collaboration protocol
#
# Gemini is an expected part of this assessment. The notebook is configured with assessment-specific instructions. Every Gemini response should end with an **AI TRAIL** containing:
#
# `[CLARIFICATION]` — assumptions, definitions, questions or refinements
# `[MAIN CHANGE]` — the main implementation/model/data/experimental change
# `[CRITICAL]` — risks, alternative explanations, disagreements or validation checks
# `[INTERPRETATION]` — what the evidence currently does or does not support
#
# You will submit a **full copy of every Gemini conversation materially used for this assessment**. The full transcript is an audit trail and is not normally read during marking. The four selected interactions in Section 9 are the evidence normally used to mark critical AI collaboration.
#
# If the notebook-level Gemini instructions are not active in your Colab session, copy the complete prompt from [`gemini-instructions.md`](gemini-instructions.md) into Gemini before beginning.

# %% [markdown]
# ## 0. Reproducible setup
#
# Record the exact reference architecture version you use. Prefer importing/cloning a **pinned tag or commit** rather than copying model code into this notebook.
#
# If the reference architecture is provided in another repository, follow [`architecture-import.md`](architecture-import.md). Keep credentials out of the notebook.
#
# Fill in:
#
# - **Architecture repository:**
# - **Tag / commit:**
# - **Dataset/version:**
# - **Main library versions or environment notes:**
# - **Random seed(s):**

# %%
# Optional setup skeleton — replace the placeholders only when the architecture repository is provided.
# Prefer a pinned tag or commit so the submitted notebook remains reproducible.

ARCHITECTURE_REPO = None   # e.g. "https://github.com/org/repo.git"
ARCHITECTURE_REF = None    # e.g. "v3.0" or a commit SHA
SEED = 42

# Do not paste access tokens or passwords into this notebook.
# See architecture-import.md for recommended public/private repository workflows.

# %% [markdown]
# # 1. Question
#
# State one clear question that can be answered with evidence from the architecture.
#
# **Template**
#
# **Question:**
# **Route (A/B/C/D):**
# **Why this question matters:**
# **What would count as an informative result:**

# %% [markdown]
# # 2. Motivation and prediction
#
# Connect the question to ideas from the module. Explain what you expect **before** seeing the main result and why.
#
# **Template**
#
# **Relevant module concepts:**
# **Prediction:**
# **Reasoning:**
# **A plausible alternative outcome:**

# %% [markdown]
# # 3. Reference system
#
# Describe the version of the architecture you are starting from. Focus only on components relevant to your investigation.
#
# Include a compact diagram, shape trace, table, or short explanation where useful.
#
# **Template**
#
# **Reference version:**
# **Relevant components:**
# **Inputs / outputs:**
# **Baseline behaviour or metric:**
# **What will remain unchanged:**

# %% [markdown]
# # 4. Proposed experiment or change
#
# Design the comparison before running the main experiment.
#
# **Template**
#
# **Independent variable / intervention:**
# **Measured outcome(s):**
# **Controls / baselines:**
# **Data split and leakage precautions:**
# **Compute budget / stopping rule:**
# **What result would support the prediction:**
# **What result would weaken it:**
# **Important confounds or alternative explanations:**

# %% [markdown]
# # 5. Implementation
#
# Put the implementation here. Keep it inspectable and modular. Reuse the supplied architecture where possible rather than reproducing large blocks of reference code.
#
# For substantial Gemini-generated changes, preserve enough context that a marker can see **what changed relative to the reference system**. Small diffs, named modules, configuration tables, or focused code cells are preferable to an unexplained full rewrite.

# %%
# IMPLEMENTATION
# Add your experiment/model code below. You may add further code and Markdown cells in this section.

# %% [markdown]
# # 6. Results
#
# Present evidence compactly. Prefer the smallest set of tables, plots, examples, and diagnostics needed to answer the question.
#
# Report failures and negative results when they are informative.
#
# **Template**
#
# **Primary result:**
# **Comparison with baseline/control:**
# **Uncertainty / variation across seeds or examples (where relevant):**
# **Diagnostic or ablation result:**
# **Unexpected observation:**

# %%
# RESULTS
# Generate the figures/tables used in your argument here.

# %% [markdown]
# # 7. Interpretation
#
# Explain what the evidence supports **without overstating it**.
#
# **Template**
#
# **What the result supports:**
# **What it does not establish:**
# **Mechanistic or theoretical explanation:**
# **How it relates to the prediction:**
# **Most important remaining uncertainty:**

# %% [markdown]
# # 8. Limitations and alternative explanations
#
# Identify the strongest reason your preferred interpretation might be wrong.
#
# **Template**
#
# **Main limitation:**
# **Alternative explanation:**
# **Evidence for/against that alternative:**
# **Best next experiment if more time/compute were available:**

# %% [markdown]
# # 9. AI interaction record
#
# Select **exactly four** moments from the submitted Gemini conversation. Do not paste the whole conversation here; reference the full transcript.
#
# The quality of prompting is **not** marked. What matters is whether you retained intellectual control: checking, modifying, rejecting, testing, or interpreting AI suggestions using evidence.
#
# | Required moment | Conversation reference | Relevant AI TRAIL tag(s) | What Gemini contributed | What I decided or changed | Evidence/reason for my decision |
# |---|---|---|---|---|---|
# | 1. Framing/refining the investigation | | `[CLARIFICATION]` | | | |
# | 2. Technical/experimental decision | | `[MAIN CHANGE]` | | | |
# | 3. Critical challenge, rejection or verification | | `[CRITICAL]` | | | |
# | 4. Interpreting evidence | | `[INTERPRETATION]` | | | |
#
# Conversation references should make the corresponding turn easy to locate in the submitted full transcript.

# %% [markdown]
# # 10. What changed my mind?
#
# Identify **one claim, expectation, explanation, or Gemini suggestion that you revised because of evidence**.
#
# **Initially I thought / Gemini suggested:**
# **Evidence that challenged it:**
# **What I now think:**
# **Why this revision matters:**

# %% [markdown]
# # 11. Conclusion
#
# Answer the original question directly.
#
# A strong conclusion is short, evidence-led, and proportional to the experiment.
#
# **Template**
#
# **Answer:**
# **Most important evidence:**
# **Main qualification:**

# %% [markdown]
# # 12. Submission checklist
#
# Before submission, confirm that you have:
#
# - [ ] answered one identifiable investigation question;
# - [ ] recorded the reference architecture repository and exact tag/commit where applicable;
# - [ ] included runnable code or sufficient outputs for the marker to inspect the evidence;
# - [ ] included controls/baselines appropriate to the claim;
# - [ ] completed the four-entry AI interaction record;
# - [ ] completed **What changed my mind?**;
# - [ ] submitted a **full, chronological copy of all Gemini conversation(s) materially used for this assessment**;
# - [ ] declared any redactions (credentials only) in the transcript;
# - [ ] kept the explanatory prose within the assessment word limit;
# - [ ] checked that figures/tables have readable labels and the notebook opens correctly.
