# %% [markdown]
# <a href="https://colab.research.google.com/github/aljiro/dnnls_lecture_notes_exercises/blob/main/notebooks/week4_investigations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![DNNLS_Logo.png](data:image/png;base64,...)

# %% [markdown]
# # Week 4 - Experiments
#
# Follow the instructions for each experiment in the repository. For every prompt, copy the indicated text into Gemini and use its response to carry out the investigation in this notebook.
#
# **Experiment repository:** [dnnls_lecture_notes_exercises](https://github.com/aljiro/dnnls_lecture_notes_exercises)
